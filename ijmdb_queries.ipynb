# %% [markdown]
# # SIESTA 2019, IJM Changes, Simple Query Examples

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# %load_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autopandas=True

# %%
pd.set_option('display.max_colwidth', 100)

# %%
# %sql postgresql://mpinzger@localhost:5432/retrofit
# Out:
# 'Connected: mpinzger@retrofit'

# %%
# %sql \dt change_schema.*
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 4 rows affected.
#           Schema          Name   Type     Owner
# 0  change_schema       changes  table  postgres
# 1  change_schema        commit  table  postgres
# 2  change_schema  filerevision  table  postgres
# 3  change_schema       project  table  postgres

# %% [markdown]
# ## How many different (Java) files have been changed?

# %%
# %sql SELECT count(distinct filename) FROM change_schema.filerevision;
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 1 rows affected.
#    count
# 0    421

# %% [markdown]
# ## How often did each file change?

# %%
# %sql SELECT filename, COUNT(*) FROM change_schema.filerevision GROUP BY filename ORDER BY count DESC;
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 421 rows affected.
#                                                                                    filename  \
# 0                                          retrofit/src/main/java/retrofit/RestAdapter.java
# 1                                       retrofit/src/main/java/retrofit/RequestBuilder.java
# 2                                            retrofit/src/main/java/retrofit2/Retrofit.java
# 3                                     retrofit/src/main/java/retrofit/http/RestAdapter.java
# 4                                       retrofit/src/main/java/retrofit/RestMethodInfo.java
# ..                                                                                      ...
# 416                                                sync/src/main/java/retrofit/io/Dirs.java
# 417                            retrofit-adapters/rxjava/src/main/java/retrofit2/Result.java
# 418  retrofit-converters/simplexml/src/main/java/retrofit/converter/SimpleXmlConverter.java
# 419                                           retrofit/src/main/java/retrofit/http/Raw.java
# 420                             retrofit/src/main/java/retrofit/RequestInterceptorTape.java
#
#      count
# 0       59
# 1       56
# 2       38
# 3       34
# 4       32
# ..     ...
# 416      1
# 417      1
# 418      1
# 419      1
# 420      1
#
# [421 rows x 2 columns]

# %% [markdown]
# ## How many single changes does each file have (over all commits)?

# %%
# %%sql SELECT f.filename, COUNT(changes.id)
# FROM change_schema.changes JOIN change_schema.filerevision f on changes.filerevision_id = f.id
# GROUP BY filename
# ORDER BY count DESC;
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 421 rows affected.
#                                                                                                 filename  \
# 0                                                    retrofit/src/main/java/retrofit/RequestBuilder.java
# 1                                                   retrofit/src/main/java/retrofit2/RequestFactory.java
# 2                                                       retrofit/src/main/java/retrofit/RestAdapter.java
# 3                                                  retrofit/src/main/java/retrofit/http/RestAdapter.java
# 4                                                    retrofit/src/main/java/retrofit2/ServiceMethod.java
# ..                                                                                                   ...
# 416                                                       retrofit/src/main/java/retrofit/http/Body.java
# 417  retrofit-converters/simplexml/src/main/java/retrofit2/converter/simplexml/SimpleXmlResponseBodyC...
# 418                                                        retrofit/src/main/java/retrofit2/BaseUrl.java
# 419                                                  retrofit/src/main/java/retrofit/io/TypedOutput.java
# 420                                                        retrofit/src/main/java/retrofit/Profiler.java
#
#      count
# 0     6438
# 1     5562
# 2     5146
# 3     4170
# 4     4082
# ..     ...
# 416      2
# 417      2
# 418      1
# 419      1
# 420      1
#
# [421 rows x 2 columns]

# %% [markdown]
# ## How many single changes PER change type does each file have (over all commits)?

# %%
# %%sql SELECT f.filename, c.change_type, c.action, COUNT(c.id)
# FROM change_schema.changes c JOIN change_schema.filerevision f on c.filerevision_id = f.id
# GROUP BY f.filename, c.change_type, c.action
# ORDER BY f.filename, c.change_type, c.action;
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 11510 rows affected.
#                                                             filename  \
# 0      android/src/main/java/retrofit/android/AndroidMainThread.java
# 1      android/src/main/java/retrofit/android/AndroidMainThread.java
# 2      android/src/main/java/retrofit/android/AndroidMainThread.java
# 3      android/src/main/java/retrofit/android/AndroidMainThread.java
# 4      android/src/main/java/retrofit/android/AndroidMainThread.java
# ...                                                              ...
# 11505                       sync/src/main/java/retrofit/io/Dirs.java
# 11506                       sync/src/main/java/retrofit/io/Dirs.java
# 11507                       sync/src/main/java/retrofit/io/Dirs.java
# 11508                       sync/src/main/java/retrofit/io/Dirs.java
# 11509                       sync/src/main/java/retrofit/io/Dirs.java
#
#          change_type action  count
# 0           Argument    INS      8
# 1              Class    INS      2
# 2          Condition    INS      3
# 3         Expression    INS      9
# 4         Field Read    INS      4
# ...              ...    ...    ...
# 11505    Return Type    INS      1
# 11506      Statement    INS      3
# 11507         Target    INS      1
# 11508      Throwable    INS      1
# 11509  Variable Read    INS      1
#
# [11510 rows x 4 columns]

# %% [markdown]
# ## What are the file revisions for a particular commit?

# %%
# %%sql SELECT co.commit_dst, co.commit_msg, count(distinct f.id) count_files, count(c.id) count_changes
# FROM change_schema.changes c JOIN change_schema.filerevision f ON c.filerevision_id = f.id
# JOIN change_schema.commit co ON f.revision_id = co.id
# GROUP BY co.commit_msg, co.commit_src, co.commit_dst
# ORDER BY count_changes DESC ;
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 573 rows affected.
#                                    commit_dst  \
# 0    d8fab22ab289f24caf73e2af9d486b92afdad490
# 1    a12554ea1a6b72ec98a079ece934b6e7d25b6518
# 2    2ca195069c02c48d7d862913247e08000e282439
# 3    06d449fa1e6ebbd81c807fb62dfcde76cf58e7ae
# 4    c533aab3d23a25f5b5d1b87de0fab1680e897948
# ..                                        ...
# 568  d402f551ecaef2a59270559321f5a2ae03323ae6
# 569  f520b68bb40e65bff13fca3102cf93421a5cf2dc
# 570  aa2e0a36d1bf926dade3a92cdca38f6d6ee834b3
# 571  224a81b1fcf8361a96006e1a47c9c07055329418
# 572  c7138b284fa5ebf80f9c6bf6a381023716780473
#
#                                                                                               commit_msg  \
# 0                                                                                            Mavenize.\n
# 1    Break request creation parsing out of service method\n\nThe parsing of annotations which define ...
# 2    Introduce call, call adapters, and the response type.\n\n* `Call` is the mechanism for request e...
# 3    Reorganize project for a final push toward 1.0.\n\n* Bump version to 1.0.0-SNAPSHOT.\n* Conslida...
# 4    Rename RequestFactoryParser to RequestFactory.Builder.\n\nIt's not perfectly a builder, but it f...
# ..                                                                                                   ...
# 568                                                                    Make Utils constructor private.\n
# 569                                                        Fix a few tiny issues in the retrofit docs.\n
# 570                                              Unexpected mime type should be a ConversionException.\n
# 571                                                            Deprecate our SimpleXmlConverterFactory\n
# 572                                            Add @Documented annotation for the new REST annotation.\n
#
#      count_files  count_changes
# 0             38           6150
# 1              2           5164
# 2             18           5113
# 3             32           4133
# 4             11           3594
# ..           ...            ...
# 568            1              1
# 569            1              1
# 570            1              1
# 571            1              1
# 572            1              1
#
# [573 rows x 4 columns]

# %% [markdown]
# ## What are the file revisions for a particular commit?

# %%
# %%sql select * from
# change_schema.filerevision f
# join change_schema.commit co ON f.revision_id = co.id
# where co.commit_dst = 'a12554ea1a6b72ec98a079ece934b6e7d25b6518';
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 2 rows affected.
#      id                                              filename  revision_id  \
# 0  1119  retrofit/src/main/java/retrofit2/RequestFactory.java        37127
# 1  1120   retrofit/src/main/java/retrofit2/ServiceMethod.java        37127
#
#       id  project_id                                commit_src  \
# 0  37127          35  8b8887c139c4cf13072499bafe8bb94e06903ea2
# 1  37127          35  8b8887c139c4cf13072499bafe8bb94e06903ea2
#
#                                  commit_dst  \
# 0  a12554ea1a6b72ec98a079ece934b6e7d25b6518
# 1  a12554ea1a6b72ec98a079ece934b6e7d25b6518
#
#                                                                                             commit_msg  \
# 0  Break request creation parsing out of service method\n\nThe parsing of annotations which define ...
# 1  Break request creation parsing out of service method\n\nThe parsing of annotations which define ...
#
#             timestamp
# 0 2018-06-13 16:27:27
# 1 2018-06-13 16:27:27

# %% [markdown]
# ## What are the changes of a particular commit?

# %%
# %%sql SELECT c.change_type, c.action, count(c.id) count_changes
# FROM change_schema.changes c JOIN change_schema.filerevision f ON c.filerevision_id = f.id
# JOIN change_schema.commit co ON f.revision_id = co.id
# WHERE co.commit_dst = 'a12554ea1a6b72ec98a079ece934b6e7d25b6518'
# AND f.filename like '%/ServiceMethod.java'
# GROUP BY c.change_type, c.action
# ORDER BY count_changes DESC;
# Out:
#  * postgresql://mpinzger@localhost:5432/retrofit
# 52 rows affected.
#                  change_type action  count_changes
# 0                  Statement    DEL            668
# 1              Variable Read    DEL            404
# 2                   Argument    DEL            362
# 3                    Literal    DEL            156
# 4                 Expression    DEL            138
# 5                 Field Read    DEL            133
# 6                  Condition    DEL            113
# 7              Variable Type    DEL            105
# 8              Type Argument    DEL             94
# 9                     Target    DEL             71
# 10                  Modifier    DEL             35
# 11                Assignment    DEL             32
# 12               Field Write    DEL             28
# 13                Field Type    DEL             28
# 14                 Parameter    DEL             23
# 15            Parameter Type    DEL             23
# 16                      This    DEL             21
# 17              Return Value    DEL             13
# 18             boolean Field    DEL             12
# 19                    Method    DEL             10
# 20               Return Type    DEL             10
# 21                      Loop    DEL              6
# 22              String Field    DEL              5
# 23               Field Write    UPD              5
# 24                Field Read    INS              4
# 25            Variable Write    DEL              4
# 26                  Argument    UPD              3
# 27                  Argument    MOV              3
# 28                 Statement    MOV              3
# 29                Field Read    UPD              2
# 30                Field Read    MOV              2
# 31                 Statement    INS              2
# 32           MediaType Field    DEL              2
# 33             Headers Field    DEL              2
# 34                Field Type    UPD              2
# 35  ParameterHandler[] Field    UPD              2
# 36             Pattern Field    DEL              2
# 37                 Statement    UPD              2
# 38      Annotation[][] Field    DEL              1
# 39        Annotation[] Field    DEL              1
# 40                 Condition    UPD              1
# 41                    Target    MOV              1
# 42                    Target    UPD              1
# 43                Assignment    INS              1
# 44  ParameterHandler[] Field    MOV              1
# 45                Type Field    MOV              1
# 46              Type[] Field    DEL              1
# 47               Field Write    MOV              1
# 48             Variable Read    INS              1
# 49                  Argument    INS              1
# 50             HttpUrl Field    DEL              1
# 51                 Set Field    DEL              1
